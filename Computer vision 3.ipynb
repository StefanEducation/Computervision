# %%
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import numpy as np
import warnings

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
import numpy as np
# reshape the data
X_train = X_train.reshape((X_train.shape[0], 28, 28))
X_test = X_test.reshape((X_test.shape[0], 28, 28))
# change the type to float
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# convert data to 3 channels
X_train = np.stack((X_train,)*3, axis=-1)
X_test = np.stack((X_test,)*3, axis=-1)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# data augmentation with generator
train_generator = ImageDataGenerator(
    rescale = 1./255,  # normalization of images
    rotation_range = 40, # augmention of images to avoid overfitting
    shear_range = 0.2,
    zoom_range = 0.2,
    fill_mode = 'nearest'
)

val_generator = ImageDataGenerator(rescale = 1./255)

train_iterator = train_generator.flow(X_train, y_train, batch_size=512, shuffle=True)

val_iterator = val_generator.flow(X_test, y_test, batch_size=512, shuffle=False)

# %%
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

# %%
model = Sequential()
# add the pretrained model
model.add(ResNet50(include_top=False, pooling='avg', weights='imagenet'))
# add fully connected layer with output
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# set resnet layers not trainable
model.layers[0].trainable=False
model.summary()

# %%
import keras
from keras import layers
los=keras.losses.Poisson(reduction="sum_over_batch_size", name="poisson")

# %%
model.compile(optimizer='Adam', loss=los, metrics=['accuracy'])

# %%
model.fit(train_iterator, epochs=10,batch_size=64, validation_data=val_iterator)
# Out:
# Epoch 1/10
# 118/118 [==============================] - 11s 91ms/step - loss: 0.1222 - accuracy: 0.9303 - val_loss: 0.1197 - val_accuracy: 0.9385
# Epoch 2/10
# 118/118 [==============================] - 11s 91ms/step - loss: 0.1222 - accuracy: 0.9298 - val_loss: 0.1180 - val_accuracy: 0.9415
# Epoch 3/10
# 118/118 [==============================] - 11s 92ms/step - loss: 0.1225 - accuracy: 0.9272 - val_loss: 0.1195 - val_accuracy: 0.9377
# Epoch 4/10
# 118/118 [==============================] - 11s 94ms/step - loss: 0.1213 - accuracy: 0.9316 - val_loss: 0.1181 - val_accuracy: 0.9411
# Epoch 5/10
# 118/118 [==============================] - 11s 93ms/step - loss: 0.1216 - accuracy: 0.9309 - val_loss: 0.1199 - val_accuracy: 0.9353
# Epoch 6/10
# 118/118 [==============================] - 11s 91ms/step - loss: 0.1217 - accuracy: 0.9309 - val_loss: 0.1182 - val_accuracy: 0.9413
# Epoch 7/10
# 118/118 [==============================] - 11s 91ms/step - loss: 0.1215 - accuracy: 0.9315 - val_loss: 0.1191 - val_accuracy: 0.9378
# Epoch 8/10
# 118/118 [==============================] - 11s 91ms/step - loss: 0.1212 - accuracy: 0.9321 - val_loss: 0.1204 - val_accuracy: 0.9316
# Epoch 9/10
# 118/118 [==============================] - 11s 92ms/step - loss: 0.1218 - accuracy: 0.9312 - val_loss: 0.1187 - val_accuracy: 0.9404
# Epoch 10/10
# 118/118 [==============================] - 11s 92ms/step - loss: 0.1213 - accuracy: 0.9309 - val_loss: 0.1179 - val_accuracy: 0.9435
